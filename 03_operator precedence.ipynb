# %%
2*4/2
# Out:
# 4.0

# %%
4%4%5%7
# Out:
# 0

# %%
3**2**2
# Out:
# 81

# %%
code=int(input("Enter a code"))
# Out:
# Enter a code 400

# %%
match code:
    case 200:
        print("ok")
    case 400:  
        print("bad request")
    case 404:
        print("not found")
    case 500:
        print("internal server issue")
    case _:
        print("nothing is match")
# Out:
# bad request

# %%
a=56.7876472

# %%
print(f"value of a {a:.2f}")
print(f"value of a {a}")
# Out:
# value of a 56.79
# value of a 56.7876472

# %%
name="abhay"

# %%
print(f"{name:>10}")
print(f"{name:<10}")
print(f"{name:^10}")
# Out:
#      abhay
# abhay
#   abhay

# %%
items=['apple','banana','grapes']

# %%
for item in items:
    pass#do nothing
print("fruits")
# Out:
# fruits

# %%
a=(1,)

# %%
type(a)
# Out:
# int

# %%
len(a)
# Out:
# 1

# %%
a[0]
# Out:
# 1
