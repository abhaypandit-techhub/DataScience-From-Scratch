# %%
import json

# %%
obj={"name":"abhay","company":"IBM","salary":4500}

# %%
json.dumps(obj)
# Out:
# '{"name": "abhay", "company": "IBM", "salary": 4500}'

# %%
ap=json.loads('{"name":"abhay","company":"IBM","salary":4500}')
ap#loads data from string
# Out:
# {'name': 'abhay', 'company': 'IBM', 'salary': 4500}

# %%
a=json.dumps(obj)
type(a)
# Out:
# str

# %%
print(a)# in print quote does not show
# Out:
# {"name": "abhay", "company": "IBM", "salary": 4500}

# %%
with open("data.txt","w") as f:
    f.write(json.dumps(obj,indent=2))

# %%
f.close()

# %%
import json

data = {"name": "Alice", "age": 30}

result = json.dumps(data)
print(result)        # '{"name": "Alice", "age": 30}'
print(type(result))  # <class 'str'>
