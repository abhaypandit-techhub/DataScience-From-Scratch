# %%
f=open("text.txt","r")

# %%
content=f.read()
content
# Out:
# '!---Hi,i am undergraduate student aspiring genrative AI engineer---!'

# %%
f.close()

# %%
info="I am currently working on RAG based application---!"

# %%
f=open("tec.txt","w")

# %%
f.write(info)
# Out:
# 51

# %%
f.close()

# %%
with open("tec.txt","r") as f:
    print(f.read())
# Out:
# I am currently working on RAG based application---!

# %%
import os

# %%
os.getcwd()# we get current working directory
# Out:
# 'C:\\Users\\Dipak Kumar\\Data Science'

# %%
os.remove("garbage.txt")# garbage file get remove

# %%
os.mkdir("rough")

# %%
os.path.exists("tec.txt")
# Out:
# True
