# %%
a=55

# %%
b=5

# %%
a/b
# Out:
# 11.0

# %%
a//b#flooer division
# Out:
# 11

# %%
a%b
# Out:
# 0

# %%
a>b
# Out:
# True

# %%
a is b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a==b#conditional operator
# Out:
# False

# %%
a=45#assignment operator

# %%
b**2
# Out:
# 25

# %%
b=25

# %%
a==b
# Out:
# True

# %%
a=25

# %%
a>=b
# Out:
# True

# %%
d=input("enter a number a")
# Out:
# enter a number a 45

# %%
e=input("Enter a number b")
# Out:
# Enter a number b 45

# %%
a+b
# Out:
# 50

# %%
d+e
# Out:
# '4545'

# %%
int(d)+int(e)
# Out:
# 90

# %%
list1=[34,49,402]

# %%
if 34 in list:
    print("correct")
# Out:
# correct

# %%
s="ap-cd-pd"
s.split("-")
# Out:
# ['ap', 'cd', 'pd']
