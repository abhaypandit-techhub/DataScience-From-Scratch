# %%
a=5

# %%
b=10

# %%
a+b
# Out:
# 15

# %%
c="abhay"

# %%
d="87ap"

# %%
print("hello world")#it is print hello world
# Out:
# hello world

# %%
# this is single commnent 
"""
hi 
i am abhay
"""
# Out:
# '\nhi \ni am abhay\n'

# %%
print(type(a))
type(d)
# Out:
# <class 'int'>
# str

# %%
a="456"

# %%
b="378"

# %%
a+b #string concatenate in this case
# Out:
# '456378'

# %% [markdown]
# If we need to add string a and b then what we do?

# %%
int(a)+int(b)#typecasting through we add this two string
# Out:
# 834

# %%
name="abhay pandit"
name.endswith("IT")#it show end string end with It or not
# Out:
# False

# %%
name.endswith("it")
# Out:
# True

# %%
name.count("a")
# Out:
# 3

# %%
name[::-1]
# Out:
# 'tidnap yahba'

# %%
name.upper()
# Out:
# 'ABHAY PANDIT'

# %%
len(name)
# Out:
# 12

# %%
name[0:]
# Out:
# 'abhay pandit'

# %%
name[-1:]
# Out:
# 't'

# %%
name="abhay"

# %%
name[-5:-1]
# Out:
# 'abha'
