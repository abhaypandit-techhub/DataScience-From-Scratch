# %%
import seaborn as sns
import numpy as np

# %%
# sns.set_theme(style="dark") # background color with no grid
sns.set_theme(style="darkgrid")

# %%
x=np.array([2,4,6,8,45,2,5,45,90,84])

# %%
y=np.sin(x) # sin2,sin4,....

# %%
sns.lineplot(x=x,y=y) # x and y variable already define that's why we cann't use quote
# sns.lineplot(x='x',y='y')
# Out:
# <Axes: >

# %% [markdown]
# sns.scatterplot()
# sns.lineplot()
# sns.barplot()
# sns.histplot()
# sns.boxplot()
# sns.violinplot()
# sns.countplot()
# sns.heatmap()
