# %%
import pandas as pd

# %%
df=pd.read_excel("BollywoodData.xlsx")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan           Bhool Bhulaiyaa  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...

# %%
df["Actor"] #single column
# Out:
# 0         Shah Rukh Khan
# 1            Salman Khan
# 2             Aamir Khan
# 3          Ranbir Kapoor
# 4          Ranveer Singh
# 5     Ayushmann Khurrana
# 6          Rajkummar Rao
# 7         Hrithik Roshan
# 8           Akshay Kumar
# 9          Kartik Aaryan
# 10          Varun Dhawan
# 11         Vicky Kaushal
# Name: Actor, dtype: object

# %%
df["Actor"][8]#specific actor
# Out:
# 'Akshay Kumar'

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[["Actor","IMDb"]]# multiple column
# Out:
#                  Actor  IMDb
# 0       Shah Rukh Khan   7.2
# 1          Salman Khan   6.0
# 2           Aamir Khan   8.4
# 3        Ranbir Kapoor   5.6
# 4        Ranveer Singh   7.0
# 5   Ayushmann Khurrana   8.3
# 6        Rajkummar Rao   7.5
# 7       Hrithik Roshan   6.5
# 8         Akshay Kumar   7.0
# 9        Kartik Aaryan   5.9
# 10        Varun Dhawan   6.1
# 11       Vicky Kaushal   8.2

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan           Bhool Bhulaiyaa  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...

# %%
df.loc[3] #it gives data using labeled row,eg. df.loc["a"]
# Out:
# Actor                    Ranbir Kapoor
# Film                        Brahmastra
# Year                              2022
# Genre                          Fantasy
# BoxOffice (INR Crore)              431
# IMDb                               5.6
# Name: 3, dtype: object

# %%
df.iloc[3]#it gives data using position number
# Out:
# Actor                    Ranbir Kapoor
# Film                        Brahmastra
# Year                              2022
# Genre                          Fantasy
# BoxOffice (INR Crore)              431
# IMDb                               5.6
# Name: 3, dtype: object

# %%
print(df.loc[4,"IMDb"]) # row represent before comma , column represent after comma
# Out:
# 7.0

# %%
df.iloc[4,1]#row represent before comma , column represent after comma using index
# Out:
# 'Padmaavat'

# %%
df.loc[0:2]# 2 also included in this case
# Out:
#             Actor             Film  Year      Genre  BoxOffice (INR Crore)  \
# 0  Shah Rukh Khan          Pathaan  2023     Action                   1050
# 1     Salman Khan  Tiger Zinda Hai  2017     Action                    565
# 2      Aamir Khan           Dangal  2016  Biography                   2024
#
#    IMDb
# 0   7.2
# 1   6.0
# 2   8.4

# %%
df.loc[0:2,["Actor","IMDb","Film"]]
# Out:
#             Actor  IMDb             Film
# 0  Shah Rukh Khan   7.2          Pathaan
# 1     Salman Khan   6.0  Tiger Zinda Hai
# 2      Aamir Khan   8.4           Dangal

# %%
df.iloc[0:3,0:3] # here in iloc case 3 is excluded
# Out:
#             Actor             Film  Year
# 0  Shah Rukh Khan          Pathaan  2023
# 1     Salman Khan  Tiger Zinda Hai  2017
# 2      Aamir Khan           Dangal  2016

# %%
df.at[0,"Actor"]#fast access for particular element access
# Out:
# 'Shah Rukh Khan'

# %%
df["IMDb"]>6 #it makes boolean series
# Out:
# 0      True
# 1     False
# 2      True
# 3     False
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10     True
# 11     True
# Name: IMDb, dtype: bool

# %%
df[df["IMDb"]>6] # it print row where condition is true
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice (INR Crore)  IMDb
# 0                    1050   7.2
# 2                    2024   8.4
# 4                     585   7.0
# 5                     111   8.3
# 6                     180   7.5
# 7                     475   6.5
# ...

# %% [markdown]
# # NOTES: Single square bracket for single column and for mutiple column for double square bracket

# %%
df[df["IMDb"]>6]["Actor"] # for specific column required
# Out:
# 0         Shah Rukh Khan
# 2             Aamir Khan
# 4          Ranveer Singh
# 5     Ayushmann Khurrana
# 6          Rajkummar Rao
# 7         Hrithik Roshan
# 8           Akshay Kumar
# 10          Varun Dhawan
# 11         Vicky Kaushal
# Name: Actor, dtype: object

# %%
df[df["IMDb"]>6][["Actor","Year"]] # for multiple column required
# Out:
#                  Actor  Year
# 0       Shah Rukh Khan  2023
# 2           Aamir Khan  2016
# 4        Ranveer Singh  2018
# 5   Ayushmann Khurrana  2018
# 6        Rajkummar Rao  2018
# 7       Hrithik Roshan  2019
# 8         Akshay Kumar  2019
# 10        Varun Dhawan  2017
# 11       Vicky Kaushal  2019

# %%
df[(df["IMDb"]>7) & (df["Year"]>=2019)]
# Out:
#              Actor                      Film  Year   Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019  Action
#
#     BoxOffice (INR Crore)  IMDb
# 0                    1050   7.2
# 11                    342   8.2

# %%
df[(df["IMDb"]>6) | (df["Year"]>2018)]
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan           Bhool Bhulaiyaa  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice (INR Crore)  IMDb
# 0                    1050   7.2
# 2                    2024   8.4
# ...

# %% [markdown]
# SPECIAL METHOD FOR CONDITION CHECK

# %%
df.query("Year>2019")#SPECIAL METHOD
# Out:
#             Actor             Film  Year          Genre  \
# 0  Shah Rukh Khan          Pathaan  2023         Action
# 3   Ranbir Kapoor       Brahmastra  2022        Fantasy
# 9   Kartik Aaryan  Bhool Bhulaiyaa  2022  Horror Comedy
#
#    BoxOffice (INR Crore)  IMDb
# 0                   1050   7.2
# 3                    431   5.6
# 9                    266   5.9

# %%
# df.query("Year > 2018 & IMDb >7")#bad
df.query("Year > 2018 and IMDb >7")#good
# Out:
#              Actor                      Film  Year   Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019  Action
#
#     BoxOffice (INR Crore)  IMDb
# 0                    1050   7.2
# 11                    342   8.2

# %%
df.query("Year > 2017 and 6 < IMDb < 7")
# Out:
#             Actor Film  Year   Genre  BoxOffice (INR Crore)  IMDb
# 7  Hrithik Roshan  War  2019  Action                    475   6.5

# %% [markdown]
# # NOTES: pandas doesn't gurantee you get copy , make use .copy() for no risk
# # Tips: whenever you need to work with segment of part then always use .copy()

# %%
df2=df[["Actor","Film"]].copy()

# %%
df2
# Out:
#                  Actor                      Film
# 0       Shah Rukh Khan                   Pathaan
# 1                Abhay           Tiger Zinda Hai
# 2           Aamir Khan                    Dangal
# 3        Ranbir Kapoor                Brahmastra
# 4        Ranveer Singh                 Padmaavat
# 5   Ayushmann Khurrana                 Andhadhun
# 6        Rajkummar Rao                     Stree
# 7       Hrithik Roshan                       War
# 8         Akshay Kumar                Good Newwz
# 9        Kartik Aaryan           Bhool Bhulaiyaa
# 10        Varun Dhawan     Badrinath Ki Dulhania
# 11       Vicky Kaushal  Uri: The Surgical Strike

# %%
df2.loc[1,"Actor"]="Kunal"
# Out:
# C:\Users\Dipak Kumar\AppData\Local\Temp\ipykernel_4656\2345676338.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.loc[1,"Actor"]="Kunal"

# %%
df2
# Out:
#                  Actor                      Film
# 0       Shah Rukh Khan                   Pathaan
# 1                Kunal           Tiger Zinda Hai
# 2           Aamir Khan                    Dangal
# 3        Ranbir Kapoor                Brahmastra
# 4        Ranveer Singh                 Padmaavat
# 5   Ayushmann Khurrana                 Andhadhun
# 6        Rajkummar Rao                     Stree
# 7       Hrithik Roshan                       War
# 8         Akshay Kumar                Good Newwz
# 9        Kartik Aaryan           Bhool Bhulaiyaa
# 10        Varun Dhawan     Badrinath Ki Dulhania
# 11       Vicky Kaushal  Uri: The Surgical Strike

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan           Bhool Bhulaiyaa  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...
