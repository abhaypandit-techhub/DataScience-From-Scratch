# %%
import pandas as pd

# %%
s=pd.Series([23,46,67,89,86])#single column

# %%
print(type(s))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(s)
# Out:
# 0    23
# 1    46
# 2    67
# 3    89
# 4    86
# dtype: int64

# %%
s
# Out:
# 0    23
# 1    46
# 2    67
# 3    89
# 4    86
# dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s2=pd.Series([23,46,67,89,86],index=["Abhay","Kunal","Alok","Bittu","Ram"])

# %%
s2
# Out:
# Abhay    23
# Kunal    46
# Alok     67
# Bittu    89
# Ram      86
# dtype: int64

# %%
s2["Abhay"]
# Out:
# np.int64(23)

# %%
print(s[0])#label represent in future version
# Out:
# 23
# C:\Users\Dipak Kumar\AppData\Local\Temp\ipykernel_1060\612857994.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(s[0])#label represent in future version

# %%
s.loc["Ram"] #for label data
# Out:
# np.int64(86)

# %%
s2.iloc[0] #for position
# Out:
# np.int64(23)

# %% [markdown]
# # CREATING DATAFRAME USING DICTIONARY

# %%
data={"name":["Abhay","Ram","Rohan","Rakesh","Mohan"],
      "age":[18,19,17,20,21],
      "City":["muz","pat","madh","nal","sam"]
     }

# %%
pd.DataFrame(data) # it genrate a data in tabular form
# Out:
#      name  age  City
# 0   Abhay   18   muz
# 1     Ram   19   pat
# 2   Rohan   17  madh
# 3  Rakesh   20   nal
# 4   Mohan   21   sam

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#      name  age  City
# 0   Abhay   18   muz
# 1     Ram   19   pat
# 2   Rohan   17  madh
# 3  Rakesh   20   nal
# 4   Mohan   21   sam

# %%
df.index # it shows index start and end
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'City'], dtype='object')

# %%
df=pd.read_excel("data.xlsx")

# %%
df
# Out:
#        Name School  Marks
# 0     Abhay   GSPS     83
# 1     Kunal    RMV     81
# 2  Himanshu   GSPS     78
# 3       Ram    STM     90
# 4    Mahesh    LTM     98

# %%
df=pd.read_csv("data.csv")#read from csv

# %%
df
# Out:
#        Name School  Marks
# 0     Abhay   GSPS     83
# 1     Kunal    RMV     81
# 2  Himanshu   GSPS     78
# 3       Ram    STM     90
# 4    Mahesh    LTM     98
