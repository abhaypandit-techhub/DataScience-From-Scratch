# %%
a={}

# %%
type(a)
# Out:
# dict

# %%
b=set()

# %%
type(b)
# Out:
# set

# %%
s={"ap","ap",4,4}

# %%
s#order is unimportant
# Out:
# {4, 'ap'}

# %%
len(s)#not repited element comes in set
# Out:
# 2

# %%
s.update({4,8,0})
s
# Out:
# {0, 4, 8, 'ap'}

# %%
s.remove(0)
print(s)
# Out:
# {'ap', 4, 8}

# %%
table=[2*i for i in range(1,11) if i%2==0]#list comprehensive similary for set and dictionary 
table
# Out:
# [4, 8, 12, 16, 20]

# %%
cube=lambda x: x*x*x
cube(3)
# Out:
# 27

# %%
sum = lambda a,b :a+b
sum(4,6)
# Out:
# 10

# %%
dict={}#empty dictionary

# %%
dicts={"name":"abhay","age":20,"grade":'A'}

# %%
dicts["name"]
# Out:
# 'abhay'

# %%
dicts.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
r=dicts.get("name")
r
# Out:
# 'abhay'

# %%
r=dicts.get("name4")
print(r)
# Out:
# None

# %%
dicts['age']=45 # update value
dicts
# Out:
# {'name': 'abhay', 'age': 45, 'grade': 'A'}

# %%
dicts.values()
# Out:
# dict_values(['abhay', 45, 'A'])

# %%
dicts.items()
# Out:
# dict_items([('name', 'abhay'), ('age', 45), ('grade', 'A')])

# %%
dict2={"name":"kunal","age":21,"hoby":"gaming"}#name variable same  then value get updated

# %%
dicts.update(dict2)
dicts
# Out:
# {'name': 'kunal', 'age': 21, 'grade': 'A', 'hoby': 'gaming', 'name1': 'kunal'}
