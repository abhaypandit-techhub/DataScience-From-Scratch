# %%
import numpy as np

# %%
arr=np.array([2,4,6,8])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.astype("float64")
# Out:
# array([2., 4., 6., 8.])

# %%
arr.nbytes
# Out:
# 32

# %%
arr_new=arr.astype("float32")

# %%
arr_new.nbytes
# Out:
# 16

# %%
arr_new.dtype
# Out:
# dtype('float32')

# %%
arr2=np.array(['ap','ac'])

# %%
print(arr2)
# Out:
# ['ap' 'ac']

# %% [markdown]
# COMPLEX NUMBER

# %%
arr3=np.array([1+2j,3+5j,6])
arr
# Out:
# array([1.+2.j, 3.+5.j, 6.+0.j])

# %%
arr4=np.array([2+4j,1+2j,3])

# %%
print(arr3+arr4)
# Out:
# [3.+6.j 4.+7.j 9.+0.j]

# %%
arr4.dtype
# Out:
# dtype('complex128')

# %%
arr_dict=np.array([{'a':1},[6,7],'hello'],dtype=object)

# %%
print(arr_dict)
# Out:
# [{'a': 1} list([6, 7]) 'hello']

# %%
arr_dict.dtype
# Out:
# dtype('O')
