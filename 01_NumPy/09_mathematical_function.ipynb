# %%
import numpy as np

# %%
arr=np.array([1,2,3,4,5])

# %%
print(np.min(arr))
# Out:
# 1

# %%
print(np.max(arr))
# Out:
# 5

# %%
print(np.sum(arr))
# Out:
# 15

# %%
print(np.mean(arr))
# Out:
# 3.0

# %%
np.prod(arr)
# Out:
# np.int64(120)

# %%
np.var(arr)
# Out:
# np.float64(2.0)

# %%
np.std(arr)
# Out:
# np.float64(1.4142135623730951)

# %%
print(np.median(arr))
# Out:
# 3.0

# %%
arr2=np.array([1,2,3,4,5,6])

# %%
np.median(arr2)
# Out:
# np.float64(3.5)

# %%
np.percentile(arr2,6)
# Out:
# np.float64(1.3)

# %%
np.argmin(arr)
# Out:
# np.int64(0)

# %%
np.argmax(arr)
# Out:
# np.int64(5)

# %%
arr2=np.array([1,2,2,3,4,5])

# %%
np.unique(arr2)
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.cumsum(arr2)
# Out:
# array([ 1,  3,  5,  8, 12, 17])
